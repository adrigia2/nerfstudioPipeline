# %%
from datasets import load_dataset

# %%
dataset = load_dataset("imagefolder", data_dir="D:/blender_renderingv2", split="train")
# Out:
# Resolving data files:   0%|          | 0/2624 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['image', 'description'],
#     num_rows: 2584
# })

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Recupera e visualizza l'immagine
img = dataset[0]["image"]  # Immagine come PngImageFile
text = dataset[0]["description"]  # Testo come stringa
img.show()  # Apri l'immagine con il visualizzatore di immagini predefinito

# Oppure, visualizza con Matplotlib
plt.imshow(img)
plt.axis("off")
plt.title(text)
plt.show()

# %% [markdown]
# Login in hugging face using command:
# ```bash
# huggingface-cli login
# ```

# %%
dataset.push_to_hub("Your/dataset_name")
# Out:
# ...
# Uploading the dataset shards: 100%|██████████| 3/3 [11:36<00:00, 232.22s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/AdrianoC/rubber_duck_extended_tokens/commit/ec8a6b4e5dfe49c470aa3bd7138ccad2ed39edf4', commit_message='Upload dataset', commit_description='', oid='ec8a6b4e5dfe49c470aa3bd7138ccad2ed39edf4', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/AdrianoC/rubber_duck_extended_tokens', endpoint='https://huggingface.co', repo_type='dataset', repo_id='AdrianoC/rubber_duck_extended_tokens'), pr_revision=None, pr_num=None)
